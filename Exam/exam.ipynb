# %% [markdown]
# //task1 //
# # Swechhya Tamrakar #
# ## Computing ##
# ### c7684020 ###
# #### I am submitting Exam paper 2.

# %% [markdown]
# //task 2//
# ## How I Work Best in Programming
#
# ### Tools and Setup
# I work best when I use **simple, reliable tools** and a calm environment. I prefer *VS Code* or *Jupyter Notebook* because they help me focus on the code rather than setup problems. A quiet room and a clear desk help me think logically and avoid distractions.
#
# ### Working Style
# My productivity improves when I:
# - Break problems into smaller steps
# - Test code frequently
# - Read error messages carefully
#
# I also like to keep short notes while coding, as this helps me remember ideas. Overall, I work best when I am organised, relaxed, and able to concentrate for longer periods of time.

# %%
#task 3

# Prompt the user to enter an exam mark
mark = int(input("Enter your exam mark: "))

# Check if the mark is a pass 
if mark >= 40:
    print("Pass")
else:
     print("Fail")
# Out:
# Fail
